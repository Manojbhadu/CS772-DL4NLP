# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
from keras.preprocessing.sequence import pad_sequences
import re
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Activation, Flatten
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import seaborn as sns
import gensim
import gensim.downloader
from nltk.corpus import brown
import string

# %%
sents = brown.sents()
cleaned_sents = []
for i in sents:
    sentence = []
    for j in i :
        if j not in string.punctuation :
            sentence.append(j.lower())
    cleaned_sents.append(sentence)

# %%
model = gensim.models.Word2Vec(cleaned_sents,size=50,window=7,min_count=1)

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train['reviews']
# Out:
# 0        This book was very informative, covering all a...
# 1        I am already a baseball fan and knew a bit abo...
# 2        I didn't like this product it smudged all unde...
# 3        I simply love the product. I appreciate print ...
# 4        It goes on very easily and makes my eyes look ...
#                                ...
# 49995                         it does not work((((((((((((
# 49996    Really worthless, loud motor with absolutely n...
# 49997    Don't waste your money on this. It does nothin...
# 49998    Product does not remove ear wax. No suction, j...
# 49999    If you wear hearing aids these are great for r...
# Name: reviews, Length: 50000, dtype: object

# %%
def convert_to_lower(text):
    # return the reviews after convering then to lowercase
    lower_text = text.copy()
    for i in range(len(text)):
        lower_text[i] = text[i].lower()
    return lower_text

# %%
def remove_punctuation(text):
    #stop_words = set(stopwords.words('english'))
    cleanedText = []
    for test_str in text:
        res = re.sub(r'[^\w\s]', '', test_str) 
        cleanedText.append(res)
    return cleanedText

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    without_stopwords_text  = text.copy()
    for i in range(len(text)):
        without_stopwords_text[i] = [w for w in text[i] if w not in stop_words]
    return without_stopwords_text

# %%
def perform_tokenization(text):
    t = Tokenizer()
    t.fit_on_texts(text)
    encoded = t.texts_to_sequences(text)
    return encoded

# %%
def get_dicts(train):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train)
    words_to_index = tokenizer.word_index
    return words_to_index

# %%
# def gloveVector():
#     wordMapping = {}
#     fileName = ''
#     with open(fileName, 'r', encoding='UTF-8') as f:
#         for line in f:
#             w_line = line.split()
#             curr_word = w_line[0]
#             wordMapping[curr_word] = np.array(w_line[1:], dtype=np.float64)
#     return (wordMapping)

# %%
# word_to_index = get_dicts(train)
# wordMap = gloveVector()
# vocabSize = len(word_to_index)

# %%
MAX_LENGTH = 60

# %%
# def embeddingMatrix():
#     vocab_len = len(word_to_index)
#     embed_vector_len = wordMap['moon'].shape[0]
#     emb_matrix = np.zeros((vocab_len, embed_vector_len))
#     for word, index in word_to_index.items():
#     embedding_vector = wordMap.get(word)
#     if embedding_vector is not None:
#         emb_matrix[index, :] = embedding_vector
#     embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=MAX_LENGTH, weights = [emb_matrix], trainable=False)
#     return embedding_layer

# %%
def tokens(text):
    a = text.copy()
    for i in range(len(text)):
        a[i] = nltk.word_tokenize(text[i])
    return a

# %%
def perform_padding(data):
  z=[]
  for i in data:
    k = [r for j in i for r in j]
    result = np.zeros(60*50)
    result[:len(k)] = np.array(k)
    z.append(result)
  return (np.array(z,dtype='float64'))

# %%
def preprocess_data(data):
    reviews = data["reviews"]
    reviews = convert_to_lower(reviews)
    reviews = remove_punctuation(reviews)
    reviews = tokens(reviews)
    emb = []
    for i in reviews:
      tmp=[]
      for j in i:
        try:
          tmp.append(model.wv[j])
        except KeyError:
          tmp.append(np.zeros((50)))
      emb.append(tmp)
    padded = perform_padding(emb)    
    return padded

# %%
preprocessed_reviews = preprocess_data(train)

# %%
preprocessed_test_reviews = preprocess_data(test)

# %%
def softmax_activation(x):
    exp_x = np.exp(x)
    return exp_x/np.sum(exp_x)

# %%
class NeuralNetGlove:

    def __init__(self, reviews, ratings):

        self.reviews = reviews
        self.ratings = ratings

    def build_nn(self,hiddenLayers,activationHidden):
        #add the input and output layer here; you can use either tensorflow or pytorch
        self.model = Sequential()
        self.model.add(InputLayer(input_shape=(MAX_LENGTH*50,)))
        for i in range(hiddenLayers):
            self.model.add(Dense(64,activation=activationHidden))
        self.model.add(Dense(5,activation='softmax'))
        self.model.compile(loss='categorical_crossentropy', optimizer=Adam(0.0001), metrics=['accuracy'])
        self.model.summary()
        
    def train_nn(self,batch_size,epochs):
        # write the training loop here; you can use either tensorflow or pytorch
        # print validation accuracy
        y_train = tf.keras.utils.to_categorical(self.ratings,num_classes=5)
        self.history = self.model.fit(self.reviews, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)
        

    def predict(self, reviews):
        # return a list containing all the ratings predicted by the trained model
        y_pred = self.model.predict(reviews)
        pred1 = []
        for i in range(len(y_pred)):
            pred1.append(np.argmax(y_pred[i])+1)
        return pred1

# %%
train_rating_list = train['ratings'].to_list()
Y = [str(i-1) for i in train_rating_list]

# %%
###### Code to find the model with best training and test set 
def bestModelNN():
    trainAccuraciesReLU = []
    testAccuraciesReLU = []
    trainAccuraciesSigmoid = []
    testAccuraciesSigmoid = []
    
    for i in range(0,5):
        M = NeuralNetGlove(preprocessed_reviews,Y)
        M.build_nn(hiddenLayers=i,activationHidden='sigmoid')
        M.train_nn(64,15)
        y_pred = M.predict(preprocessed_test_reviews)
        accuracyTest = accuracy_score(test['ratings'],y_pred)
        accuracyTrain = M.history.history['accuracy'][-1]
        trainAccuraciesSigmoid.append(accuracyTrain)
        testAccuraciesSigmoid.append(accuracyTest)
        del M
        
    for i in range(0,5):
        M = NeuralNetGlove(preprocessed_reviews,Y)
        M.build_nn(hiddenLayers=i,activationHidden='relu')
        M.train_nn(64,15)
        y_pred = M.predict(preprocessed_test_reviews)
        accuracyTest = accuracy_score(test['ratings'],y_pred)
        accuracyTrain = M.history.history['accuracy'][-1]
        trainAccuraciesReLU.append(accuracyTrain)
        testAccuraciesReLU.append(accuracyTest)
        del M 
        
    print(trainAccuraciesReLU)
    print(testAccuraciesReLU)
    print(trainAccuraciesSigmoid)
    print(testAccuraciesSigmoid)

# %%
##### Develop Report for the best model and prediction for some examples
def report(y_pred,test,Model):
    Classification_report = classification_report(test['ratings'],y_pred,target_names=['1','2','3','4','5'])
    cm  = confusion_matrix(test['ratings'],y_pred)
    print("Classification Report : \n",Classification_report)
    print("Heat Map :\n")
    sns.heatmap(cm,cmap="Blues",annot=True,fmt='.4g',xticklabels=['1','2','3','4','5'],yticklabels=['1','2','3','4','5'])
    tried_examples = [['I like it but dont think I would buy again.'], ['Nice looking cleaner but way smaller than 2 liters. Not as advertised.'],['Total waste of money, I used all 10 of these and got 0 results from it.']] 
    # Create the pandas DataFrame 
    df = pd.DataFrame(tried_examples, columns = ['reviews']) 
    pre_tried_examples = preprocess_data(df,word_to_index)
    z = Model.predict(pre_tried_examples)
    print("Examples :\n",df)
    print("Predicted Values: \n",z)

# %%
bestModelNN()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None,
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 5)                 15005
# =================================================================
# Total params: 15,005
# Trainable params: 15,005
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.1248 - accuracy: 0.6626 - val_loss: 1.3176 - val_accuracy: 0.5714
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0157 - accuracy: 0.6846 - val_loss: 1.2410 - val_accuracy: 0.5736
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9770 - accuracy: 0.6865 - val_loss: 1.2183 - val_accuracy: 0.5775
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9551 - accuracy: 0.6878 - val_loss: 1.2040 - val_accuracy: 0.5791
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9404 - accuracy: 0.6894 - val_loss: 1.1826 - val_accuracy: 0.5827
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9297 - accuracy: 0.6911 - val_loss: 1.1765 - val_accuracy: 0.5841
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9214 - accuracy: 0.6925 - val_loss: 1.1768 - val_accuracy: 0.5862
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9149 - accuracy: 0.6931 - val_loss: 1.1850 - val_accuracy: 0.5848
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9094 - accuracy: 0.6944 - val_loss: 1.1675 - val_accuracy: 0.5874
# Epoch 10/15
# 625/625 [==============================] - 2s 4ms/step - loss: 0.9047 - accuracy: 0.6949 - val_loss: 1.1528 - val_accuracy: 0.5891
# Epoch 11/15
# 625/625 [==============================] - 2s 4ms/step - loss: 0.9008 - accuracy: 0.6959 - val_loss: 1.1537 - val_accuracy: 0.5883
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8972 - accuracy: 0.6951 - val_loss: 1.1584 - val_accuracy: 0.5896
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8940 - accuracy: 0.6969 - val_loss: 1.1442 - val_accuracy: 0.5916
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8915 - accuracy: 0.6971 - val_loss: 1.1655 - val_accuracy: 0.5890
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8890 - accuracy: 0.6978 - val_loss: 1.1622 - val_accuracy: 0.5907
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 192,389
# Trainable params: 192,389
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0503 - accuracy: 0.6815 - val_loss: 1.2359 - val_accuracy: 0.5739
# Epoch 2/15
# 625/625 [==============================] - 2s 4ms/step - loss: 0.9559 - accuracy: 0.6886 - val_loss: 1.2007 - val_accuracy: 0.5790
# Epoch 3/15
# 625/625 [==============================] - 2s 4ms/step - loss: 0.9113 - accuracy: 0.6934 - val_loss: 1.1732 - val_accuracy: 0.5874
# Epoch 4/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.8783 - accuracy: 0.6997 - val_loss: 1.1762 - val_accuracy: 0.5860
# Epoch 5/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.8503 - accuracy: 0.7050 - val_loss: 1.1752 - val_accuracy: 0.5875
# Epoch 6/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.8262 - accuracy: 0.7119 - val_loss: 1.1722 - val_accuracy: 0.5928
# Epoch 7/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8027 - accuracy: 0.7179 - val_loss: 1.1806 - val_accuracy: 0.5893
# Epoch 8/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7819 - accuracy: 0.7232 - val_loss: 1.1685 - val_accuracy: 0.5916
# Epoch 9/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.7616 - accuracy: 0.7310 - val_loss: 1.1527 - val_accuracy: 0.5929
# Epoch 10/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7433 - accuracy: 0.7372 - val_loss: 1.1971 - val_accuracy: 0.5914
# Epoch 11/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7246 - accuracy: 0.7446 - val_loss: 1.1911 - val_accuracy: 0.5940
# Epoch 12/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.7085 - accuracy: 0.7497 - val_loss: 1.2045 - val_accuracy: 0.5875
# Epoch 13/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6917 - accuracy: 0.7562 - val_loss: 1.1809 - val_accuracy: 0.5878
# Epoch 14/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6757 - accuracy: 0.7622 - val_loss: 1.1850 - val_accuracy: 0.5900
# Epoch 15/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6604 - accuracy: 0.7687 - val_loss: 1.1986 - val_accuracy: 0.5861
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_20 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 196,549
# Trainable params: 196,549
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 4s 6ms/step - loss: 1.0421 - accuracy: 0.6855 - val_loss: 1.2560 - val_accuracy: 0.5743
# Epoch 2/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9510 - accuracy: 0.6873 - val_loss: 1.1919 - val_accuracy: 0.5769
# Epoch 3/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9040 - accuracy: 0.6935 - val_loss: 1.1675 - val_accuracy: 0.5852
# Epoch 4/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8673 - accuracy: 0.6999 - val_loss: 1.1453 - val_accuracy: 0.5907
# Epoch 5/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8349 - accuracy: 0.7092 - val_loss: 1.1561 - val_accuracy: 0.5901
# Epoch 6/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8061 - accuracy: 0.7170 - val_loss: 1.1620 - val_accuracy: 0.5880
# Epoch 7/15
# 625/625 [==============================] - 3s 4ms/step - loss: 0.7797 - accuracy: 0.7251 - val_loss: 1.1548 - val_accuracy: 0.5903
# Epoch 8/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7551 - accuracy: 0.7327 - val_loss: 1.1700 - val_accuracy: 0.5882
# Epoch 9/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7321 - accuracy: 0.7411 - val_loss: 1.1747 - val_accuracy: 0.5860
# Epoch 10/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7093 - accuracy: 0.7491 - val_loss: 1.1809 - val_accuracy: 0.5831
# Epoch 11/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6886 - accuracy: 0.7577 - val_loss: 1.2223 - val_accuracy: 0.5856
# Epoch 12/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6684 - accuracy: 0.7654 - val_loss: 1.2245 - val_accuracy: 0.5817
# Epoch 13/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6493 - accuracy: 0.7721 - val_loss: 1.2402 - val_accuracy: 0.5796
# Epoch 14/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6310 - accuracy: 0.7796 - val_loss: 1.2405 - val_accuracy: 0.5741
# Epoch 15/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6140 - accuracy: 0.7856 - val_loss: 1.2669 - val_accuracy: 0.5744
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 200,709
# Trainable params: 200,709
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 4s 6ms/step - loss: 1.0582 - accuracy: 0.6727 - val_loss: 1.2527 - val_accuracy: 0.5742
# Epoch 2/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9588 - accuracy: 0.6874 - val_loss: 1.1856 - val_accuracy: 0.5847
# Epoch 3/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9148 - accuracy: 0.6916 - val_loss: 1.1638 - val_accuracy: 0.5887
# Epoch 4/15
# 625/625 [==============================] - 3s 6ms/step - loss: 0.8787 - accuracy: 0.6990 - val_loss: 1.1695 - val_accuracy: 0.5909
# Epoch 5/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8448 - accuracy: 0.7078 - val_loss: 1.1514 - val_accuracy: 0.5938
# Epoch 6/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8127 - accuracy: 0.7171 - val_loss: 1.1580 - val_accuracy: 0.5922
# Epoch 7/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7827 - accuracy: 0.7273 - val_loss: 1.1682 - val_accuracy: 0.5899
# Epoch 8/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7538 - accuracy: 0.7381 - val_loss: 1.1712 - val_accuracy: 0.5902
# Epoch 9/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7277 - accuracy: 0.7466 - val_loss: 1.1772 - val_accuracy: 0.5819
# Epoch 10/15
# 625/625 [==============================] - 3s 5ms/step - loss: 0.