# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
from keras.preprocessing.sequence import pad_sequences
import re
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Activation, Flatten
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import seaborn as sns
import gensim
import gensim.downloader
from nltk.corpus import brown
import string

# %%
sents = brown.sents()
cleaned_sents = []
for i in sents:
    sentence = []
    for j in i :
        if j not in string.punctuation :
            sentence.append(j.lower())
    cleaned_sents.append(sentence)

# %%
model = gensim.models.FastText(sentences=cleaned_sents,size=50)

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train['reviews']
# Out:
# 0        This book was very informative, covering all a...
# 1        I am already a baseball fan and knew a bit abo...
# 2        I didn't like this product it smudged all unde...
# 3        I simply love the product. I appreciate print ...
# 4        It goes on very easily and makes my eyes look ...
#                                ...
# 49995                         it does not work((((((((((((
# 49996    Really worthless, loud motor with absolutely n...
# 49997    Don't waste your money on this. It does nothin...
# 49998    Product does not remove ear wax. No suction, j...
# 49999    If you wear hearing aids these are great for r...
# Name: reviews, Length: 50000, dtype: object

# %%
def convert_to_lower(text):
    # return the reviews after convering then to lowercase
    lower_text = text.copy()
    for i in range(len(text)):
        lower_text[i] = text[i].lower()
    return lower_text

# %%
def remove_punctuation(text):
    #stop_words = set(stopwords.words('english'))
    cleanedText = []
    for test_str in text:
        res = re.sub(r'[^\w\s]', '', test_str) 
        cleanedText.append(res)
    return cleanedText

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    without_stopwords_text  = text.copy()
    for i in range(len(text)):
        without_stopwords_text[i] = [w for w in text[i] if w not in stop_words]
    return without_stopwords_text

# %%
def perform_tokenization(text):
    t = Tokenizer()
    t.fit_on_texts(text)
    encoded = t.texts_to_sequences(text)
    return encoded

# %%
def get_dicts(train):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train)
    words_to_index = tokenizer.word_index
    return words_to_index

# %%
# def gloveVector():
#     wordMapping = {}
#     fileName = ''
#     with open(fileName, 'r', encoding='UTF-8') as f:
#         for line in f:
#             w_line = line.split()
#             curr_word = w_line[0]
#             wordMapping[curr_word] = np.array(w_line[1:], dtype=np.float64)
#     return (wordMapping)

# %%
# word_to_index = get_dicts(train)
# wordMap = gloveVector()
# vocabSize = len(word_to_index)

# %%
MAX_LENGTH = 60

# %%
# def embeddingMatrix():
#     vocab_len = len(word_to_index)
#     embed_vector_len = wordMap['moon'].shape[0]
#     emb_matrix = np.zeros((vocab_len, embed_vector_len))
#     for word, index in word_to_index.items():
#     embedding_vector = wordMap.get(word)
#     if embedding_vector is not None:
#         emb_matrix[index, :] = embedding_vector
#     embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=MAX_LENGTH, weights = [emb_matrix], trainable=False)
#     return embedding_layer

# %%
def tokens(text):
    a = text.copy()
    for i in range(len(text)):
        a[i] = nltk.word_tokenize(text[i])
    return a

# %%
def perform_padding(data):
  z=[]
  for i in data:
    k = [r for j in i for r in j]
    result = np.zeros(60*50)
    result[:len(k)] = np.array(k)
    z.append(result)
  return (np.array(z,dtype='float64'))

# %%
def preprocess_data(data):
    reviews = data["reviews"]
    reviews = convert_to_lower(reviews)
    reviews = remove_punctuation(reviews)
    reviews = tokens(reviews)
    emb = []
    for i in reviews:
      tmp=[]
      for j in i:
        try:
          tmp.append(model.wv[j])
        except KeyError:
          tmp.append(np.zeros((50)))
      emb.append(tmp)
    padded = perform_padding(emb)    
    return padded

# %%
preprocessed_reviews = preprocess_data(train)

# %%
preprocessed_test_reviews = preprocess_data(test)

# %%
def softmax_activation(x):
    exp_x = np.exp(x)
    return exp_x/np.sum(exp_x)

# %%
class NeuralNetGlove:

    def __init__(self, reviews, ratings):

        self.reviews = reviews
        self.ratings = ratings

    def build_nn(self,hiddenLayers,activationHidden):
        #add the input and output layer here; you can use either tensorflow or pytorch
        self.model = Sequential()
        self.model.add(InputLayer(input_shape=(MAX_LENGTH*50,)))
        for i in range(hiddenLayers):
            self.model.add(Dense(64,activation=activationHidden))
        self.model.add(Dense(5,activation='softmax'))
        self.model.compile(loss='categorical_crossentropy', optimizer=Adam(0.0001), metrics=['accuracy'])
        self.model.summary()
        
    def train_nn(self,batch_size,epochs):
        # write the training loop here; you can use either tensorflow or pytorch
        # print validation accuracy
        y_train = tf.keras.utils.to_categorical(self.ratings,num_classes=5)
        self.history = self.model.fit(self.reviews, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)
        

    def predict(self, reviews):
        # return a list containing all the ratings predicted by the trained model
        y_pred = self.model.predict(reviews)
        pred1 = []
        for i in range(len(y_pred)):
            pred1.append(np.argmax(y_pred[i])+1)
        return pred1

# %%
train_rating_list = train['ratings'].to_list()
Y = [str(i-1) for i in train_rating_list]

# %%
###### Code to find the model with best training and test set 
def bestModelNN():
    trainAccuraciesReLU = []
    testAccuraciesReLU = []
    trainAccuraciesSigmoid = []
    testAccuraciesSigmoid = []
    
    for i in range(0,5):
        M = NeuralNetGlove(preprocessed_reviews,Y)
        M.build_nn(hiddenLayers=i,activationHidden='sigmoid')
        M.train_nn(64,15)
        y_pred = M.predict(preprocessed_test_reviews)
        accuracyTest = accuracy_score(test['ratings'],y_pred)
        accuracyTrain = M.history.history['accuracy'][-1]
        trainAccuraciesSigmoid.append(accuracyTrain)
        testAccuraciesSigmoid.append(accuracyTest)
        del M
        
    for i in range(0,5):
        M = NeuralNetGlove(preprocessed_reviews,Y)
        M.build_nn(hiddenLayers=i,activationHidden='relu')
        M.train_nn(64,15)
        y_pred = M.predict(preprocessed_test_reviews)
        accuracyTest = accuracy_score(test['ratings'],y_pred)
        accuracyTrain = M.history.history['accuracy'][-1]
        trainAccuraciesReLU.append(accuracyTrain)
        testAccuraciesReLU.append(accuracyTest)
        del M 
        
    print(trainAccuraciesReLU)
    print(testAccuraciesReLU)
    print(trainAccuraciesSigmoid)
    print(testAccuraciesSigmoid)

# %%
##### Develop Report for the best model and prediction for some examples
def report(y_pred,test,Model):
    Classification_report = classification_report(test['ratings'],y_pred,target_names=['1','2','3','4','5'])
    cm  = confusion_matrix(test['ratings'],y_pred)
    print("Classification Report : \n",Classification_report)
    print("Heat Map :\n")
    sns.heatmap(cm,cmap="Blues",annot=True,fmt='.4g',xticklabels=['1','2','3','4','5'],yticklabels=['1','2','3','4','5'])
    tried_examples = [['I like it but dont think I would buy again.'], ['Nice looking cleaner but way smaller than 2 liters. Not as advertised.'],['Total waste of money, I used all 10 of these and got 0 results from it.']] 
    # Create the pandas DataFrame 
    df = pd.DataFrame(tried_examples, columns = ['reviews']) 
    pre_tried_examples = preprocess_data(df,word_to_index)
    z = Model.predict(pre_tried_examples)
    print("Examples :\n",df)
    print("Predicted Values: \n",z)

# %%
bestModelNN()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 15005
# =================================================================
# Total params: 15,005
# Trainable params: 15,005
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 1s 2ms/step - loss: 1.2310 - accuracy: 0.6180 - val_loss: 1.3325 - val_accuracy: 0.5696
# Epoch 2/15
# 625/625 [==============================] - 1s 2ms/step - loss: 1.0250 - accuracy: 0.6817 - val_loss: 1.2653 - val_accuracy: 0.5747
# Epoch 3/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9814 - accuracy: 0.6849 - val_loss: 1.2310 - val_accuracy: 0.5769
# Epoch 4/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9591 - accuracy: 0.6873 - val_loss: 1.2166 - val_accuracy: 0.5777
# Epoch 5/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9452 - accuracy: 0.6890 - val_loss: 1.2096 - val_accuracy: 0.5788
# Epoch 6/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9352 - accuracy: 0.6901 - val_loss: 1.1873 - val_accuracy: 0.5822
# Epoch 7/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9273 - accuracy: 0.6911 - val_loss: 1.1884 - val_accuracy: 0.5826
# Epoch 8/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9213 - accuracy: 0.6914 - val_loss: 1.1825 - val_accuracy: 0.5852
# Epoch 9/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9159 - accuracy: 0.6929 - val_loss: 1.1832 - val_accuracy: 0.5864
# Epoch 10/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9119 - accuracy: 0.6931 - val_loss: 1.1815 - val_accuracy: 0.5845
# Epoch 11/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9084 - accuracy: 0.6941 - val_loss: 1.1705 - val_accuracy: 0.5881
# Epoch 12/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9051 - accuracy: 0.6940 - val_loss: 1.1840 - val_accuracy: 0.5852
# Epoch 13/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9027 - accuracy: 0.6952 - val_loss: 1.1780 - val_accuracy: 0.5854
# Epoch 14/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.8997 - accuracy: 0.6949 - val_loss: 1.1775 - val_accuracy: 0.5853
# Epoch 15/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.8975 - accuracy: 0.6958 - val_loss: 1.1762 - val_accuracy: 0.5862
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                192064
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 192,389
# Trainable params: 192,389
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0355 - accuracy: 0.6804 - val_loss: 1.2406 - val_accuracy: 0.5741
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9687 - accuracy: 0.6863 - val_loss: 1.2274 - val_accuracy: 0.5747
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9431 - accuracy: 0.6877 - val_loss: 1.1981 - val_accuracy: 0.5783
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9258 - accuracy: 0.6896 - val_loss: 1.1883 - val_accuracy: 0.5800
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9129 - accuracy: 0.6913 - val_loss: 1.1718 - val_accuracy: 0.5829
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9019 - accuracy: 0.6931 - val_loss: 1.1727 - val_accuracy: 0.5833
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8925 - accuracy: 0.6943 - val_loss: 1.1684 - val_accuracy: 0.5845
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8839 - accuracy: 0.6963 - val_loss: 1.1631 - val_accuracy: 0.5845
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8759 - accuracy: 0.6977 - val_loss: 1.1629 - val_accuracy: 0.5861
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8680 - accuracy: 0.6989 - val_loss: 1.1693 - val_accuracy: 0.5857
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8608 - accuracy: 0.7006 - val_loss: 1.1623 - val_accuracy: 0.5881
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8538 - accuracy: 0.7018 - val_loss: 1.1570 - val_accuracy: 0.5877
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8465 - accuracy: 0.7036 - val_loss: 1.1554 - val_accuracy: 0.5897
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8397 - accuracy: 0.7045 - val_loss: 1.1573 - val_accuracy: 0.5890
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8326 - accuracy: 0.7061 - val_loss: 1.1579 - val_accuracy: 0.5902
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                192064
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 196,549
# Trainable params: 196,549
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0371 - accuracy: 0.6837 - val_loss: 1.2721 - val_accuracy: 0.5742
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9963 - accuracy: 0.6863 - val_loss: 1.2311 - val_accuracy: 0.5742
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9705 - accuracy: 0.6862 - val_loss: 1.2167 - val_accuracy: 0.5742
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9499 - accuracy: 0.6862 - val_loss: 1.1979 - val_accuracy: 0.5745
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9344 - accuracy: 0.6873 - val_loss: 1.1786 - val_accuracy: 0.5778
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9224 - accuracy: 0.6896 - val_loss: 1.1706 - val_accuracy: 0.5799
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9118 - accuracy: 0.6915 - val_loss: 1.1729 - val_accuracy: 0.5808
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9028 - accuracy: 0.6934 - val_loss: 1.1592 - val_accuracy: 0.5851
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8944 - accuracy: 0.6953 - val_loss: 1.1530 - val_accuracy: 0.5868
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8864 - accuracy: 0.6963 - val_loss: 1.1578 - val_accuracy: 0.5866
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8785 - accuracy: 0.6978 - val_loss: 1.1496 - val_accuracy: 0.5904
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8706 - accuracy: 0.6990 - val_loss: 1.1499 - val_accuracy: 0.5917
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8628 - accuracy: 0.7009 - val_loss: 1.1472 - val_accuracy: 0.5911
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8554 - accuracy: 0.7030 - val_loss: 1.1506 - val_accuracy: 0.5904
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8475 - accuracy: 0.7049 - val_loss: 1.1426 - val_accuracy: 0.5930
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                192064
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 200,709
# Trainable params: 200,709
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.1524 - accuracy: 0.6258 - val_loss: 1.2888 - val_accuracy: 0.5742
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0254 - accuracy: 0.6863 - val_loss: 1.2861 - val_accuracy: 0.5742
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0140 - accuracy: 0.6863 - val_loss: 1.2650 - val_accuracy: 0.5742
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9926 - accuracy: 0.6863 - val_loss: 1.2385 - val_accuracy: 0.5742
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9715 - accuracy: 0.6863 - val_loss: 1.2263 - val_accuracy: 0.5742
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9541 - accuracy: 0.6863 - val_loss: 1.1928 - val_accuracy: 0.5742
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9406 - accuracy: 0.6863 - val_loss: 1.1834 - val_accuracy: 0.5750
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9289 - accuracy: 0.6873 - val_loss: 1.1745 - val_accuracy: 0.5783
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9192 - accuracy: 0.6891 - val_loss: 1.1668 - val_accuracy: 0.5813
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9102 - accuracy: 0.6913 - val_loss: 1.1643 - val_accuracy: 0.5827
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9013 - accuracy: 0.6934 - val_loss: 1.1577 - val_accuracy: 0.5861
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8932 - accuracy: 0.6949 - val_loss: 1.1565 - val_accuracy: 0.5888
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8855 - accuracy: 0.6970 - val_loss: 1.1551 - val_accuracy: 0.5890
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8777 - accuracy: 0.6980 - val_loss: 1.1511 - val_accuracy: 0.5907
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8697 - accuracy: 0.6999 - val_loss: 1.1432 - val_accuracy: 0.5913
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 204,869
# Trainable params: 204,869
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 4ms/step - loss: 1.1702 - accuracy: 0.6101 - val_loss: 1.2935 - val_accuracy: 0.5742
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0270 - accuracy: 0.6863 - val_loss: 1.2947 - val_accuracy: 0.5742
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0243 - accuracy: 0.6863 - val_loss: 1.2872 - val_accuracy: 0.5742
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0122 - accuracy: 0.6863 - val_loss: 1.2603 - val_accuracy: 0.5742
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9889 - accuracy: 0.6863 - val_loss: 1.2288 - val_accuracy: 0.5742
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9681 - accuracy: 0.6863 - val_loss: 1.2097 - val_accuracy: 0.5742
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9547 - accuracy: 0.6863 - val_loss: 1.2003 - val_accuracy: 0.5742
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9443 - accuracy: 0.6864 - val_loss: 1.1797 - val_accuracy: 0.5752
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9356 - accuracy: 0.6872 - val_loss: 1.1876 - val_accuracy: 0.5781
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9271 - accuracy: 0.6887 - val_loss: 1.1788 - val_accuracy: 0.5819
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9181 - accuracy: 0.6898 - val_loss: 1.1764 - val_accuracy: 0.5838
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9083 - accuracy: 0.6902 - val_loss: 1.1646 - val_accuracy: 0.5867
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8981 - accuracy: 0.6914 - val_loss: 1.1635 - val_accuracy: 0.5874
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8866 - accuracy: 0.6929 - val_loss: 1.1626 - val_accuracy: 0.5886
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8738 - accuracy: 0.6949 - val_loss: 1.1468 - val_accuracy: 0.5913
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 5)                 15005
# =================================================================
# Total params: 15,005
# Trainable params: 15,005
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 1s 2ms/step - loss: 1.2165 - accuracy: 0.6294 - val_loss: 1.3282 - val_accuracy: 0.5715
# Epoch 2/15
# 625/625 [==============================] - 1s 2ms/step - loss: 1.0265 - accuracy: 0.6836 - val_loss: 1.2571 - val_accuracy: 0.5757
# Epoch 3/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9824 - accuracy: 0.6865 - val_loss: 1.2377 - val_accuracy: 0.5770
# Epoch 4/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9593 - accuracy: 0.6884 - val_loss: 1.2135 - val_accuracy: 0.5788
# Epoch 5/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9453 - accuracy: 0.6899 - val_loss: 1.2000 - val_accuracy: 0.5812
# Epoch 6/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9345 - accuracy: 0.6909 - val_loss: 1.1938 - val_accuracy: 0.5821
# Epoch 7/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9267 - accuracy: 0.6920 - val_loss: 1.1915 - val_accuracy: 0.5829
# Epoch 8/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9207 - accuracy: 0.6923 - val_loss: 1.1829 - val_accuracy: 0.5822
# Epoch 9/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9158 - accuracy: 0.6934 - val_loss: 1.1881 - val_accuracy: 0.5840
# Epoch 10/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9113 - accuracy: 0.6941 - val_loss: 1.1770 - val_accuracy: 0.5857
# Epoch 11/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9080 - accuracy: 0.6938 - val_loss: 1.1751 - val_accuracy: 0.5849
# Epoch 12/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9044 - accuracy: 0.6946 - val_loss: 1.1804 - val_accuracy: 0.5857
# Epoch 13/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.9021 - accuracy: 0.6948 - val_loss: 1.1792 - val_accuracy: 0.5845
# Epoch 14/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.8994 - accuracy: 0.6949 - val_loss: 1.1765 - val_accuracy: 0.5868
# Epoch 15/15
# 625/625 [==============================] - 1s 2ms/step - loss: 0.8973 - accuracy: 0.6948 - val_loss: 1.1673 - val_accuracy: 0.5884
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 192,389
# Trainable params: 192,389
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 3ms/step - loss: 1.0922 - accuracy: 0.6632 - val_loss: 1.2659 - val_accuracy: 0.5727
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9533 - accuracy: 0.6895 - val_loss: 1.2422 - val_accuracy: 0.5755
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9007 - accuracy: 0.6974 - val_loss: 1.2049 - val_accuracy: 0.5779
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8627 - accuracy: 0.7055 - val_loss: 1.2079 - val_accuracy: 0.5795
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8327 - accuracy: 0.7131 - val_loss: 1.1919 - val_accuracy: 0.5819
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8056 - accuracy: 0.7199 - val_loss: 1.1946 - val_accuracy: 0.5823
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7822 - accuracy: 0.7276 - val_loss: 1.2085 - val_accuracy: 0.5813
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7599 - accuracy: 0.7355 - val_loss: 1.1986 - val_accuracy: 0.5838
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7408 - accuracy: 0.7403 - val_loss: 1.1956 - val_accuracy: 0.5808
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7225 - accuracy: 0.7486 - val_loss: 1.2043 - val_accuracy: 0.5814
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7051 - accuracy: 0.7544 - val_loss: 1.2192 - val_accuracy: 0.5789
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6888 - accuracy: 0.7602 - val_loss: 1.2336 - val_accuracy: 0.5790
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6730 - accuracy: 0.7666 - val_loss: 1.2348 - val_accuracy: 0.5774
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6591 - accuracy: 0.7723 - val_loss: 1.2449 - val_accuracy: 0.5788
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6450 - accuracy: 0.7779 - val_loss: 1.2560 - val_accuracy: 0.5772
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_20 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 196,549
# Trainable params: 196,549
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 4ms/step - loss: 1.0755 - accuracy: 0.6701 - val_loss: 1.2558 - val_accuracy: 0.5741
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9592 - accuracy: 0.6881 - val_loss: 1.2321 - val_accuracy: 0.5771
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9100 - accuracy: 0.6933 - val_loss: 1.2110 - val_accuracy: 0.5809
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8701 - accuracy: 0.7013 - val_loss: 1.2064 - val_accuracy: 0.5828
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8351 - accuracy: 0.7111 - val_loss: 1.2047 - val_accuracy: 0.5834
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8040 - accuracy: 0.7218 - val_loss: 1.2175 - val_accuracy: 0.5831
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7762 - accuracy: 0.7309 - val_loss: 1.2050 - val_accuracy: 0.5776
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7492 - accuracy: 0.7388 - val_loss: 1.2021 - val_accuracy: 0.5806
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7261 - accuracy: 0.7468 - val_loss: 1.2153 - val_accuracy: 0.5771
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7033 - accuracy: 0.7553 - val_loss: 1.2280 - val_accuracy: 0.5788
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6829 - accuracy: 0.7621 - val_loss: 1.2341 - val_accuracy: 0.5732
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6635 - accuracy: 0.7707 - val_loss: 1.2537 - val_accuracy: 0.5779
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6456 - accuracy: 0.7770 - val_loss: 1.2707 - val_accuracy: 0.5730
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6280 - accuracy: 0.7843 - val_loss: 1.2707 - val_accuracy: 0.5644
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6112 - accuracy: 0.7915 - val_loss: 1.2874 - val_accuracy: 0.5633
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 200,709
# Trainable params: 200,709
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 4ms/step - loss: 1.0630 - accuracy: 0.6768 - val_loss: 1.2616 - val_accuracy: 0.5743
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9627 - accuracy: 0.6871 - val_loss: 1.2188 - val_accuracy: 0.5749
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9166 - accuracy: 0.6914 - val_loss: 1.2164 - val_accuracy: 0.5766
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8770 - accuracy: 0.6994 - val_loss: 1.1885 - val_accuracy: 0.5803
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8410 - accuracy: 0.7093 - val_loss: 1.1790 - val_accuracy: 0.5825
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8079 - accuracy: 0.7178 - val_loss: 1.1793 - val_accuracy: 0.5807
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7761 - accuracy: 0.7282 - val_loss: 1.1943 - val_accuracy: 0.5796
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7474 - accuracy: 0.7389 - val_loss: 1.2122 - val_accuracy: 0.5777
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7204 - accuracy: 0.7473 - val_loss: 1.2083 - val_accuracy: 0.5767
# Epoch 10/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6961 - accuracy: 0.7536 - val_loss: 1.2548 - val_accuracy: 0.5722
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6730 - accuracy: 0.7633 - val_loss: 1.2676 - val_accuracy: 0.5697
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6505 - accuracy: 0.7720 - val_loss: 1.2899 - val_accuracy: 0.5697
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6299 - accuracy: 0.7792 - val_loss: 1.3186 - val_accuracy: 0.5647
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6109 - accuracy: 0.7868 - val_loss: 1.3182 - val_accuracy: 0.5626
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5902 - accuracy: 0.7944 - val_loss: 1.3627 - val_accuracy: 0.5541
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 64)                192064
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_27 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 204,869
# Trainable params: 204,869
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 625/625 [==============================] - 2s 4ms/step - loss: 1.0634 - accuracy: 0.6694 - val_loss: 1.2591 - val_accuracy: 0.5742
# Epoch 2/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9598 - accuracy: 0.6869 - val_loss: 1.2258 - val_accuracy: 0.5745
# Epoch 3/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9163 - accuracy: 0.6916 - val_loss: 1.1971 - val_accuracy: 0.5784
# Epoch 4/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8760 - accuracy: 0.6993 - val_loss: 1.1900 - val_accuracy: 0.5831
# Epoch 5/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8392 - accuracy: 0.7118 - val_loss: 1.2010 - val_accuracy: 0.5815
# Epoch 6/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.8033 - accuracy: 0.7218 - val_loss: 1.2069 - val_accuracy: 0.5776
# Epoch 7/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7707 - accuracy: 0.7343 - val_loss: 1.2049 - val_accuracy: 0.5695
# Epoch 8/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7392 - accuracy: 0.7440 - val_loss: 1.2439 - val_accuracy: 0.5797
# Epoch 9/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7085 - accuracy: 0.7554 - val_loss: 1.2529 - val_accuracy: 0.5696
# Epoch 10/15
# 625/625 [==============================] - 2s 4ms/step - loss: 0.6817 - accuracy: 0.7651 - val_loss: 1.2776 - val_accuracy: 0.5694
# Epoch 11/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6567 - accuracy: 0.7731 - val_loss: 1.2934 - val_accuracy: 0.5643
# Epoch 12/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6309 - accuracy: 0.7820 - val_loss: 1.3193 - val_accuracy: 0.5627
# Epoch 13/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6082 - accuracy: 0.7899 - val_loss: 1.3657 - val_accuracy: 0.5662
# Epoch 14/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5873 - accuracy: 0.7986 - val_loss: 1.3738 - val_accuracy: 0.5555
# Epoch 15/15
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5675 - accuracy: 0.8077 - val_loss: 1.4050 - val_accuracy: 0.5435
# [0.6947500109672546, 0.777899980545044, 0.7915250062942505, 0.7943999767303467, 0.807699978351593]
# [0.5879, 0.5839, 0.5715, 0.5708, 0.5542]
# [0.6957749724388123, 0.7061499953269958, 0.7049499750137329, 0.6998500227928162, 0.6949250102043152]
# [0.5875, 0.5914, 0.5924, 0.5951, 0.5941]
